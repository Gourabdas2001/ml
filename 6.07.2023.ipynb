# %%
import pandas as pd
import numpy as np

# %%
#request package foe online dataset

# %%
df=pd.read_csv(r"C:\Users\goura\Downloads\CWML\insurance.csv")

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
len(dir(df))
# Out:
# 444

# %%
df[55:66]
# Out:
#     age     sex   bmi  children smoker     region  expenses
# 55   58    male  37.0         2    yes  northwest  47496.49
# 56   58  female  31.8         2     no  northeast  13607.37
# 57   18    male  31.7         2    yes  southeast  34303.17
# 58   53  female  22.9         1    yes  southeast  23244.79
# 59   34  female  37.3         2     no  northwest   5989.52
# 60   43    male  27.4         3     no  northeast   8606.22
# 61   25    male  33.7         4     no  southeast   4504.66
# 62   64    male  24.7         1     no  northwest  30166.62
# 63   28  female  25.9         1     no  northwest   4133.64
# 64   20  female  22.4         0    yes  northwest  14711.74
# 65   19  female  28.9         0     no  southwest   1743.21

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df.keys()
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
df_region=df["region"]

# %%
type(df_region)
# Out:
# pandas.core.series.Series

# %%
df_region.ndim
# Out:
# 1

# %%
df.ndim
# Out:
# 2

# %%
y=df["expenses"]

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
#pandas operation
#Descriptice stats
#Inferntial
#Predictive"""

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
df.describe()#children is normaly distubated
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.sample(5,random_state=101)#ramdom sample is fixed for every run
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 44     38    male  37.1         1     no  northeast   6079.67
# 134    20  female  28.8         0     no  northeast   2457.21
# 980    54    male  25.5         1     no  northeast  25517.11
# 618    19  female  33.1         0    yes  southeast  34439.86
# 1238   37    male  22.7         3     no  northeast   6985.51

# %%
df["age"].mean()
# Out:
# 39.20702541106129

# %%
df["age"].std()
# Out:
# 14.049960379216172

# %%
df_female=df[df["sex"]=="female"]

# %%
df_female.reset_index()
# Out:
#      index  age     sex   bmi  children smoker     region  expenses
# 0        0   19  female  27.9         0    yes  southwest  16884.92
# 1        5   31  female  25.7         0     no  southeast   3756.62
# 2        6   46  female  33.4         1     no  southeast   8240.59
# 3        7   37  female  27.7         3     no  northwest   7281.51
# 4        9   60  female  25.8         0     no  northwest  28923.14
# ..     ...  ...     ...   ...       ...    ...        ...       ...
# 657   1332   52  female  44.7         3     no  southwest  11411.69
# 658   1334   18  female  31.9         0     no  northeast   2205.98
# 659   1335   18  female  36.9         0     no  southeast   1629.83
# 660   1336   21  female  25.8         0     no  southwest   2007.95
# 661   1337   61  female  29.1         0    yes  northwest  29141.36
#
# [662 rows x 8 columns]

# %%
df_female.drop("index",axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_female.drop("index",axis=0)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
# ...

# %%
df_female[df_female["children"]>2]
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 7      37  female  27.7         3     no  northwest   7281.51
# 25     59  female  27.7         3     no  southeast  14001.13
# 32     19  female  28.6         5     no  southwest   4687.80
# 36     62  female  33.0         3     no  northwest  15612.19
# 54     40  female  28.7         3     no  northwest   8059.68
# ...   ...     ...   ...       ...    ...        ...       ...
# 1246   45  female  25.7         3     no  southwest   9101.80
# 1253   40  female  29.3         4     no  southwest  15828.82
# 1256   51  female  36.4         3     no  northwest  11436.74
# 1314   30  female  23.7         3    yes  northwest  18765.88
# 1332   52  female  44.7         3     no  southwest  11411.69
#
# [96 rows x 7 columns]

# %%
df_female[df_female["age"]>29]
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 5      31  female  25.7         0     no  southeast   3756.62
# 6      46  female  33.4         1     no  southeast   8240.59
# 7      37  female  27.7         3     no  northwest   7281.51
# 9      60  female  25.8         0     no  northwest  28923.14
# 11     62  female  26.3         0    yes  southeast  27808.73
# ...   ...     ...   ...       ...    ...        ...       ...
# 1323   42  female  40.4         2    yes  southeast  43896.38
# 1326   42  female  32.9         0     no  northeast   7050.02
# 1330   57  female  25.7         2     no  southeast  12629.17
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [461 rows x 7 columns]

# %%
df_female
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 5      31  female  25.7         0     no  southeast   3756.62
# 6      46  female  33.4         1     no  southeast   8240.59
# 7      37  female  27.7         3     no  northwest   7281.51
# 9      60  female  25.8         0     no  northwest  28923.14
# ...   ...     ...   ...       ...    ...        ...       ...
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [662 rows x 7 columns]

# %%
#loc by name#iloc by position

# %%
df.iloc[:,0:3]
# Out:
#       age     sex   bmi
# 0      19  female  27.9
# 1      18    male  33.8
# 2      28    male  33.0
# 3      33    male  22.7
# 4      32    male  28.9
# ...   ...     ...   ...
# 1333   50    male  31.0
# 1334   18  female  31.9
# 1335   18  female  36.9
# 1336   21  female  25.8
# 1337   61  female  29.1
#
# [1338 rows x 3 columns]

# %%
df.loc[50:100,"age":"region"]
# Out:
#      age     sex   bmi  children smoker     region
# 50    18  female  35.6         0     no  northeast
# 51    21  female  33.6         2     no  northwest
# 52    48    male  28.0         1    yes  southwest
# 53    36    male  34.4         0    yes  southeast
# 54    40  female  28.7         3     no  northwest
# 55    58    male  37.0         2    yes  northwest
# 56    58  female  31.8         2     no  northeast
# 57    18    male  31.7         2    yes  southeast
# 58    53  female  22.9         1    yes  southeast
# 59    34  female  37.3         2     no  northwest
# 60    43    male  27.4         3     no  northeast
# 61    25    male  33.7         4     no  southeast
# 62    64    male  24.7         1     no  northwest
# 63    28  female  25.9         1     no  northwest
# 64    20  female  22.4         0    yes  northwest
# 65    19  female  28.9         0     no  southwest
# 66    61  female  39.1         2     no  southwest
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x="sex",data=df,hue="region")
plt.show()

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# C:\Users\goura\AppData\Local\Temp\ipykernel_1096\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# age         0.055673
# bmi         0.284593
# children    0.938380
# expenses    1.515880
# dtype: float64

# %%
sns.displot(data=df,x="age")

# %%
sns.displot(data=df,x="age",hue="sex")

# %%
sns.displot(data=df,x="age",hue="sex",element="step")

# %%
sns.displot(data=df,x="age",kind="kde")

# %%
sns.displot(data=df,x="age",hue="region",kind="kde")

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df.plot()
plt.show()

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.barplot(data=df).set()
# Out:
# []
